# %%
import pandas as pd



# قراءة ملف Excel

df = pd.read_excel('D:Hemorrhagic fever.xlsx')

# رسم التوزيع حسب الجنس
from matplotlib import pyplot as plt
import seaborn as sns

# الرسم بناءً على توزيع الجنس
df.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# الرسم بناءً على نوع المنطقة
df.groupby('type of area').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# الرسم بناءً على مصدر العدوى
df.groupby('source of infection').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# توزيع الأعمار
df['age'].plot(kind='hist', bins=20, title='Age Distribution')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# توزيع النزيف
# Plot histogram for bleeding-related columns
df[['bleeding from injection sites', 'bleeding form body orfices ', 'gum bleeding', 
    'conjectivitis', 'subcotanous bleeding']].plot(kind='hist', bins=20, alpha=0.5, title='Bleeding Distribution', stacked=True)

# Customize the plot
plt.gca().spines[['top', 'right']].set_visible(False)
plt.xlabel('Bleeding Symptoms Count')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# Read Excel file
df = pd.read_excel('D:Hemorrhagic fever.xlsx')

# Set general style, color, and font size
color = '#4682B4'
font_size = 20  # Set font size for axis labels
tick_font_size = font_size - 2
fig_size = (12, 8)  # Set figure size for all plots
hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']  # Define different hatch patterns
print('Statistics');
# Plot gender distribution with different textures
plt.figure(figsize=fig_size)
ax = df.groupby('gender').size().plot(kind='barh', color=color, edgecolor='black')
for i, bar in enumerate(ax.patches):
    bar.set_hatch(hatches[i % len(hatches)])
plt.title('Distribution by Gender', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Gender', fontsize=font_size)
plt.xticks(fontsize=tick_font_size)
plt.yticks(fontsize=tick_font_size)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig("gender_distribution.png", format="png", dpi=300)
plt.show()

# Plot distribution by type of area with different textures
plt.figure(figsize=fig_size)
ax = df.groupby('type of area').size().plot(kind='barh', color=color, edgecolor='black')
for i, bar in enumerate(ax.patches):
    bar.set_hatch(hatches[i % len(hatches)])
plt.title('Distribution by Type of Area', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Gender', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Type of Area', fontsize=font_size)
plt.xticks(fontsize=tick_font_size)
plt.yticks(fontsize=tick_font_size)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig("type_of_area_distribution.png", format="png", dpi=300)
plt.show()

plt.figure(figsize=fig_size)
ax = df.groupby('source of infection').size().plot(kind='barh', color=color, edgecolor='black')
# Group by 'source of infection' and get the count
# Plot distribution by source of infection with different textures
plt.figure(figsize=fig_size)
ax = df.groupby('source of infection').size().plot(kind='barh', color=color, edgecolor='black')
for i, bar in enumerate(ax.patches):
    bar.set_hatch(hatches[i % len(hatches)])
plt.title('Distribution by Source of Infection', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Source of Infection', fontsize=font_size)

# Set diagonal tick labels on the x-axis
plt.xticks(rotation=45, ha='right')  # ha='right' aligns the labels to the right
# Set diagonal tick labels on the y-axis
plt.yticks(rotation=75, fontsize=tick_font_size)  # Rotate y-ticks to 45 degrees

plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig("source_of_infection_distribution.png", format="png", dpi=300)
plt.show()
plt.figure(figsize=fig_size)
df['age'].plot(kind='hist', bins=20, color=color, edgecolor='black')
plt.title('Age Distribution', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Gender', fontsize=font_size)
plt.xlabel('Age', fontsize=font_size)
plt.ylabel('Frequency', fontsize=font_size)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig("age_distribution.png", format="png", dpi=300)
plt.show()

# Plot bleeding distribution with different textures and font adjustments
plt.figure(figsize=fig_size)
ax = df[['bleeding from injection sites', 'bleeding form body orfices ', 'gum bleeding', 
         'conjectivitis', 'subcotanous bleeding']].plot(kind='hist', bins=20, alpha=0.5, 
                                                        stacked=True, color=color, edgecolor='black')
for i, patch in enumerate(ax.patches):
    patch.set_hatch(hatches[i % len(hatches)])

plt.title('Bleeding Symptoms Distribution', fontsize=font_size)
plt.xlabel('Count', fontsize=font_size)
plt.ylabel('Gender', fontsize=font_size)
plt.xlabel('Bleeding Symptoms Count', fontsize=font_size)
plt.ylabel('Frequency', fontsize=font_size)
plt.legend(loc='upper right', fontsize=font_size - 2)

# Set diagonal tick labels on the x-axis
plt.xticks(rotation=45, ha='right')  # ha='right' aligns the labels to the right
plt.yticks(rotation=45, fontsize=tick_font_size)  # Rotate y-ticks to 45 degrees

plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig("bleeding_distribution.png", format="png", dpi=300)
plt.show()
# Out:
# Statistics

# %%
# المعالجة الناجحة التي طورت النتائج معالجة البيانات قبل تقسيمها
# Read the Excel file
import numpy as np
from sklearn.preprocessing import LabelEncoder
df = pd.read_excel('D:Hemorrhagic fever.xlsx')
# Drop unnecessary columns
df.drop(['_Record your current location_latitude','_Record your current location_longitude','YEAR', 'Month', 'Month number', 'date of investigation', 'patient name',
         'province', 'district', 'address/district', 'address/subdistrict', 'address/locality', 'village',
         'address/point','phone', 'clinical features', 'fever','hospital name',
         'date of blood sample taken', 'date of blood sample receipt', 'blood sample status',
         'Lab result', 'duration between sample taken and lab recived',
         'Are there animals near the residence?', 'Are there ticks on animals or in barns?',
         'Was an animal slaughtered during the current month inside the house?',
         'Is there any contact with a similar case?',
         'Are there any confirmed previous infections in the same residential area?'], axis=1, inplace=True)
# Ensure date columns are in datetime format
df['date of onset'] = pd.to_datetime(df['date of onset'], errors='coerce')
df['date of admission'] = pd.to_datetime(df['date of admission'], errors='coerce')
df['date of discharge'] = pd.to_datetime(df['date of discharge'], errors='coerce')
df['date of death'] = pd.to_datetime(df['date of death'], errors='coerce')

# Calculate OnsetToAdmission
df['OnsetToAdmission'] = (df['date of admission'] - df['date of onset']).dt.days

# Calculate OnsetToOutcome
df['OnsetToOutcome'] = np.where(df['patient out come'] == 'recover',
                                (df['date of discharge'] - df['date of onset']).dt.days,
                                (df['date of death'] - df['date of onset']).dt.days)

# Ensure that missing or invalid dates are handled correctly
df['OnsetToOutcome'] = df['OnsetToOutcome'].fillna(-1)  # Use -1 for cases with missing data

# Separate features (X) and labels (y)
X1 = df.drop('patient out come', axis=1)  # All columns except 'patient out come'
y1 = df['patient out come']  # Outcome labels

# Map age groups to class numbers
age_group_mapping = {
    'less than 5': 0,
    '5--14': 1,
    '15--44': 2,
    '45--64': 3,
    '65+': 4
}

# Apply the mapping
df['age groups'] = df['age groups'].map(age_group_mapping)
# Handle missing data in other columns
# For numerical columns, fill missing values with the mode
numerical_columns = [ 'age groups','age','OnsetToAdmission', 'OnsetToOutcome','days in hospitalisation','type of area']  # List any other numerical columns
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mode().iloc[0])

# For The columns that are not required to be all filled for one patient record, fill missing values with the zeros
BinaryNumerical_columns = ['bleeding from injection sites' , 'bleeding form body orfices ' , 'gum bleeding','conjectivitis','subcotanous bleeding','bloody diarrhoae','heamaturia' ]  # List any other numerical columns
df[BinaryNumerical_columns] = df[BinaryNumerical_columns].fillna(0)
# Sum all bleeding symptoms in one column
#df['bleeding']=df['bloody diarrhoae']+df['heamaturia']+df['bleeding from injection sites']+df[  'bleeding form body orfices ']+df[  'gum bleeding']+df['conjectivitis']+df['subcotanous bleeding']
df['bleeding']=df['bleeding from injection sites']+df[  'bleeding form body orfices ']+df[  'gum bleeding']+df['conjectivitis']+df['subcotanous bleeding']
# For categorical columns, fill missing values with the mode (most frequent value)
categorical_columns = ['gender', 'occupation', 'source of infection', 'patient out come','type of area']  # List other categorical columns
df[categorical_columns] = df[categorical_columns].apply(lambda x: x.fillna(x.mode()[0]))

# Label Encoding for all categorical columns
label_encoder = LabelEncoder()
print(df['patient out come'])
print("Missing values in 'patient out come:", df['patient out come'].isnull().sum())
# Apply label encoding to each categorical column
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])
print("Missing values in Labeled 'patient out come:", df['patient out come'].isnull().sum())

df['patient out come'].plot(kind='hist', bins=20, title='patient out come')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
print(df.head(15))

#df.drop(['bloody diarrhoae','heamaturia','bleeding from injection sites' , 'bleeding form body orfices ' , 'gum bleeding','conjectivitis','subcotanous bleeding'], axis=1, inplace=True)
df.drop(['bleeding from injection sites' , 'bleeding form body orfices ' , 'gum bleeding','conjectivitis','subcotanous bleeding'], axis=1, inplace=True)

df.drop(['age groups','occupation','gender','source of infection','type of area'] , axis=1, inplace=True)
df.drop(['date of onset','date of admission','date of discharge','date of death'], axis=1, inplace=True)

# Filter out rows with any remaining missing or irrelevant data
#df = df.dropna()  # Drop any rows that still have missing data after handling





df.to_excel('D:HemoAfterCleaning.xlsx', index=False, engine='openpyxl')



# Separate features (X) and labels (y)
X1 = df.drop('patient out come', axis=1)  # All columns except 'patient out come'
y1 = df['patient out come']  # Outcome labels



from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)

X1=X_train
y1=y_train

from sklearn.preprocessing import MinMaxScaler
# Perform Min-Max scaling on the data between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))

X1 = pd.DataFrame(scaler.fit_transform(X1), columns=X1.columns)

X_test = pd.DataFrame(scaler.fit_transform(X_test), columns=X_test.columns)



print( X1.shape)
print( y1.shape)


# Check for missing values
print("Missing values in y1:", y1.isnull().sum())
# Out:
# 0        death
# 1        death
# 2        death
# 3        death
# 4      recover
#         ...
# 355    recover
# 356    recover
# 357    recover
# 358    recover
# 359    recover
# Name: patient out come, Length: 360, dtype: object
# Missing values in 'patient out come: 0
# Missing values in Labeled 'patient out come: 0
#     age  age groups  gender  occupation  source of infection date of onset  \
# 0    33           2       1           7                    0    2018-06-20
# 1    51           3       0           6                    0    2021-06-23
# 2    17           2       0           9                    0    2021-07-04
# 3    20           2       1           0                    2    2021-09-12
# 4    16           2       1           9                    2    2021-09-14
# 5    20           2       0           6                    0    2021-09-18
# 6    37           2       1           1                    2    2021-09-20
# ...

# %%
#رسم ال heat map
import seaborn as sns
import matplotlib.pyplot as plt

# Calculating the correlation matrix
correlation_matrix = df.corr()

# Plotting the correlation matrix
plt.figure(figsize=(7, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
#plt.savefig('correlation_matrix.png', format='png', dpi=300)
plt.show()

# %%
# استيراد المكتبات الأساسية

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE




# قراءة ملف Excel
df = pd.read_excel('D:HemoAfterCleaning.xlsx')
# Separate features (X) and labels (y)
X1 = df.drop('patient out come', axis=1)  # All columns except 'patient out come'
y1 = df['patient out come']  # Outcome labels

# تقسيم البيانات إلى مجموعات التدريب والاختبار
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)
plt.figure(figsize=(8, 8))
y_train.value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightblue', 'yellow'])
plt.title('Class Distribution of Patient Outcome Before Balancing')
plt.ylabel('')  # Removes the default y-label
plt.show()


# تطبيق SMOTE لمعالجة عدم التوازن في الفئات
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# مقياس Min-Max Scaling لتحسين الدقة
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_smote = pd.DataFrame(scaler.fit_transform(X_train_smote), columns=X_train_smote.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# طباعة حجم البيانات بعد المعالجة
print("Shape of X_train_smote:", X_train_smote.shape)
print("Shape of y_train_smote:", y_train_smote.shape)
# Out:
# Shape of X_train_smote: (396, 7)
# Shape of y_train_smote: (396,)

# %%
#=================== SMOTE
#   KFold best of each model   استيراد المكتبات الأساسية
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import pickle
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
# قراءة ملف Excel
df = pd.read_excel('D:HemoAfterCleaning.xlsx')

# فصل المتغيرات المستقلة والتابعة
X1 = df.drop('patient out come', axis=1)
y1 = df['patient out come']

# تقسيم البيانات إلى مجموعات التدريب والاختبار
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)

smoteen = SMOTEENN(random_state=42)
X_Smote, y_Smote = smoteen.fit_resample(X_train, y_train)
X_train=X_Smote
y_train=y_Smote
print("Shape of y_train_smote:", y_train.shape)
print("Shape of y_test_smote:", y_test.shape)

#================================================== TRAINING

# إعداد النماذج
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machine': SVC(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier()
}

# Define display labels based on unique classes in y_test
display_labels = np.unique(y_test)

# إعداد Stratified K-Fold Cross-Validation with 3 folds
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Dictionary to store the best model for each type
best_models = {}
best_scores = {}

# تدريب النماذج وتقييم الأداء باستخدام Cross-Validation
for model_name, model in models.items():
    print(f"{model_name} Model")
    
    # حساب الدقة لكل نموذج باستخدام Cross-Validation
    cross_val_scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='accuracy')
    mean_cv_score = np.mean(cross_val_scores)
    print(f"Cross-Validation Accuracy Scores: {cross_val_scores}")
    print(f"Mean Cross-Validation Accuracy: {mean_cv_score:.2%}")
    
    # Check if this model is the best for its type
    if model_name not in best_scores or mean_cv_score > best_scores[model_name]:
        best_scores[model_name] = mean_cv_score
        best_models[model_name] = model
        print(f"New best model for {model_name} saved.")

# تقييم النموذج الأفضل لكل نوع واختباره على بيانات الاختبار
for model_name, best_model in best_models.items():
    # Train the best model on the entire training set
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    
    print(f"\n{model_name} - Best Model")
    print("Test Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

    # Display confusion matrix with proper class labels
    disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred), display_labels=display_labels)
    disp.plot(cmap='Blues', values_format='d')
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

        # Feature importance for Random Forest
    if model_name == 'Random Forest' and hasattr(best_model, 'feature_importances_'):
        rf_importances = best_model.feature_importances_
        feature_names = X_train.columns
        sorted_idx_rf = np.argsort(rf_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_rf], rf_importances[sorted_idx_rf])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Random Forest')
        plt.show()
         # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()

    # Feature importance for Logistic Regression
    if model_name == 'Logistic Regression' and hasattr(best_model, 'coef_'):
        lr_importances = np.abs(best_model.coef_[0])  # Get absolute coefficients for binary classification
        sorted_idx_lr = np.argsort(lr_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_lr], lr_importances[sorted_idx_lr])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Logistic Regression')
        plt.show()
        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
    if model_name == 'Gradient Boosting' and hasattr(best_model, 'feature_importances_'):
        gb_importances = best_model.feature_importances_
        sorted_idx_gb = np.argsort(gb_importances)[::-1]

        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_gb], gb_importances[sorted_idx_gb])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Gradient Boosting')
        plt.show()

        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()       
        

    # حفظ النموذج المدرب
    with open(f"{model_name}_best_model.pkl", 'wb') as file:
        pickle.dump(best_model, file)
    print(f"Best model saved as {model_name}_best_model.pkl")
    print("=" * 50)  # Separator for clarity
# Out:
# Shape of y_train: (252,)
# Shape of y_test: (108,)
# Shape of y_train_smote: (242,)
# Shape of y_test_smote: (108,)
# Decision Tree Model
# Cross-Validation Accuracy Scores: [0.96296296 0.95061728 0.9       ]
# Mean Cross-Validation Accuracy: 93.79%
# New best model for Decision Tree saved.
# Random Forest Model
# Cross-Validation Accuracy Scores: [1.         0.92592593 0.9375    ]
# Mean Cross-Validation Accuracy: 95.45%
# New best model for Random Forest saved.
# Support Vector Machine Model
# Cross-Validation Accuracy Scores: [0.97530864 0.85185185 0.925     ]
# Mean Cross-Validation Accuracy: 91.74%
# New best model for Support Vector Machine saved.
# Logistic Regression Model
# Cross-Validation Accuracy Scores: [0.98765432 0.87654321 0.9       ]
# Mean Cross-Validation Accuracy: 92.14%
# New best model for Logistic Regression saved.
# Gradient Boosting Model
# Cross-Validation Accuracy Scores: [0.97530864 0.96296296 0.9625    ]
# Mean Cross-Validation Accuracy: 96.69%
# ...

# %%
#   KFold best of each model   استيراد المكتبات الأساسية
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import pickle

# قراءة ملف Excel
df = pd.read_excel('D:HemoAfterCleaning.xlsx')

# فصل المتغيرات المستقلة والتابعة
X1 = df.drop('patient out come', axis=1)
y1 = df['patient out come']

# تقسيم البيانات إلى مجموعات التدريب والاختبار
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)

# إعداد النماذج
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machine': SVC(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier()
}

# Define display labels based on unique classes in y_test
display_labels = np.unique(y_test)

# إعداد Stratified K-Fold Cross-Validation with 3 folds
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Dictionary to store the best model for each type
best_models = {}
best_scores = {}

# تدريب النماذج وتقييم الأداء باستخدام Cross-Validation
for model_name, model in models.items():
    print(f"{model_name} Model")
    
    # حساب الدقة لكل نموذج باستخدام Cross-Validation
    cross_val_scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='accuracy')
    mean_cv_score = np.mean(cross_val_scores)
    print(f"Cross-Validation Accuracy Scores: {cross_val_scores}")
    print(f"Mean Cross-Validation Accuracy: {mean_cv_score:.2%}")
    
    # Check if this model is the best for its type
    if model_name not in best_scores or mean_cv_score > best_scores[model_name]:
        best_scores[model_name] = mean_cv_score
        best_models[model_name] = model
        print(f"New best model for {model_name} saved.")

# تقييم النموذج الأفضل لكل نوع واختباره على بيانات الاختبار
for model_name, best_model in best_models.items():
    # Train the best model on the entire training set
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    
    print(f"\n{model_name} - Best Model")
    print("Test Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

    # Display confusion matrix with proper class labels
    disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred), display_labels=display_labels)
    disp.plot(cmap='Blues', values_format='d')
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()
# Feature importance for Random Forest
    if model_name == 'Random Forest' and hasattr(best_model, 'feature_importances_'):
        rf_importances = best_model.feature_importances_
        feature_names = X_train.columns
        sorted_idx_rf = np.argsort(rf_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_rf], rf_importances[sorted_idx_rf])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Random Forest')
        plt.show()
         # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()
 # Feature importance for Logistic Regression
    if model_name == 'Logistic Regression' and hasattr(best_model, 'coef_'):
        lr_importances = np.abs(best_model.coef_[0])  # Get absolute coefficients for binary classification
        sorted_idx_lr = np.argsort(lr_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_lr], lr_importances[sorted_idx_lr])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Logistic Regression')
        plt.show()
        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
    if model_name == 'Gradient Boosting' and hasattr(best_model, 'feature_importances_'):
        gb_importances = best_model.feature_importances_
        sorted_idx_gb = np.argsort(gb_importances)[::-1]

        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_gb], gb_importances[sorted_idx_gb])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Gradient Boosting')
        plt.show()

        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()       
        
        

    # حفظ النموذج المدرب
    with open(f"{model_name}_best_model.pkl", 'wb') as file:
        pickle.dump(best_model, file)
    print(f"Best model saved as {model_name}_best_model.pkl")
    print("=" * 50)  # Separator for clarity
# Out:
# Shape of y_train: (252,)
# Shape of y_test: (108,)
# Decision Tree Model
# Cross-Validation Accuracy Scores: [0.71428571 0.71428571 0.73809524]
# Mean Cross-Validation Accuracy: 72.22%
# New best model for Decision Tree saved.
# Random Forest Model
# Cross-Validation Accuracy Scores: [0.79761905 0.8452381  0.83333333]
# Mean Cross-Validation Accuracy: 82.54%
# New best model for Random Forest saved.
# Support Vector Machine Model
# Cross-Validation Accuracy Scores: [0.78571429 0.78571429 0.78571429]
# Mean Cross-Validation Accuracy: 78.57%
# New best model for Support Vector Machine saved.
# Logistic Regression Model
# Cross-Validation Accuracy Scores: [0.82142857 0.9047619  0.83333333]
# Mean Cross-Validation Accuracy: 85.32%
# New best model for Logistic Regression saved.
# Gradient Boosting Model
# Cross-Validation Accuracy Scores: [0.76190476 0.80952381 0.82142857]
# Mean Cross-Validation Accuracy: 79.76%
# New best model for Gradient Boosting saved.
# K-Nearest Neighbors Model
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming 'models' is a dictionary containing trained models with keys as model names.
# Example: models = {'Logistic Regression': logistic_reg_model, 'Random Forest': rf_model}

# Iterate over each model to evaluate and display confusion matrix and feature importance
for model_name, model in models.items():
    print(f"Evaluating {model_name}")
    
    # Generate predictions for the test set
    y_pred = model.predict(X_test)
    
    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Define display labels based on unique classes in y_test
    display_labels = np.unique(y_test)
    
   

    # Feature importance for Random Forest
    if model_name == 'Random Forest' and hasattr(model, 'feature_importances_'):
        rf_importances = model.feature_importances_
        feature_names = X_train.columns
        sorted_idx_rf = np.argsort(rf_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_rf], rf_importances[sorted_idx_rf])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Random Forest')
        plt.show()
         # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()

    # Feature importance for Logistic Regression
    if model_name == 'Logistic Regression' and hasattr(model, 'coef_'):
        lr_importances = np.abs(model.coef_[0])  # Get absolute coefficients for binary classification
        sorted_idx_lr = np.argsort(lr_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_lr], lr_importances[sorted_idx_lr])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Logistic Regression')
        plt.show()
        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
    if model_name == 'Gradient Boosting' and hasattr(model, 'feature_importances_'):
        gb_importances = model.feature_importances_
        sorted_idx_gb = np.argsort(gb_importances)[::-1]

        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_gb], gb_importances[sorted_idx_gb])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Gradient Boosting')
        plt.show()

        # Display confusion matrix with proper class labels
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Confusion Matrix - {model_name}")
        plt.show()       
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        plt.show()
# Out:
# Evaluating Decision Tree
# Evaluating Random Forest
# Evaluating Support Vector Machine
# Evaluating Logistic Regression
# Evaluating Gradient Boosting
# Evaluating K-Nearest Neighbors

# %%
# استيراد المكتبات الأساسية     OLD

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
import pickle



# قراءة ملف Excel
df = pd.read_excel('D:HemoAfterCleaningOld.xlsx')

#رسم ال heat map Old
import seaborn as sns
import matplotlib.pyplot as plt

# Calculating the correlation matrix
correlation_matrix = df.corr()

# Plotting the correlation matrix
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1,annot_kws={"size": 8})
plt.title('Correlation Matrix')
#plt.savefig('correlation_matrix.png', format='png', dpi=300)
plt.show()






# فصل المتغيرات المستقلة والتابعة
X1 = df.drop('patient out come', axis=1)
y1 = df['patient out come']

# تقسيم البيانات إلى مجموعات التدريب والاختبار
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)

# تطبيق SMOTE لمعالجة عدم التوازن في الفئات
#smote = SMOTE(random_state=42)
#X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# مقياس Min-Max Scaling لتحسين الدقة
#scaler = MinMaxScaler(feature_range=(0, 1))
#X_train_smote = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
#X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# طباعة حجم البيانات بعد المعالجة
#print("Shape of X_train_smote:", X_train_smote.shape)
#print("Shape of y_train_smote:", y_train_smote.shape)

# -------------------------------------
# تطبيق خوارزميات تعلم الآلة المختلفة مع Cross-Validation
# -------------------------------------

# إعداد النماذج
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machine': SVC(random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier()
}





# إعداد Stratified K-Fold Cross-Validation with 3 folds
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# تدريب النماذج وتقييم الأداء باستخدام Cross-Validation
for model_name, model in models.items():
    print(f"{model_name} Model")
    
    # حساب الدقة لكل نموذج باستخدام Cross-Validation
    cross_val_scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='accuracy')
    print(f"Cross-Validation Accuracy Scores: {cross_val_scores}")
    print(f"Mean Cross-Validation Accuracy: {np.mean(cross_val_scores):.2%}")
    
    # تدريب النموذج على بيانات التدريب المتوازنة وتقييمه على بيانات الاختبار
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Test Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
     # حفظ النموذج المدرب
    with open(f"{model_name}_model_New.pkl", 'wb') as file:
        pickle.dump(model, file)
    print(f"Model saved as {model_name}_model_New.pkl")
    print("=" * 50)  # Separator for clarity
# Out:
# Decision Tree Model
# Cross-Validation Accuracy Scores: [0.72619048 0.73809524 0.66666667]
# Mean Cross-Validation Accuracy: 71.03%
# Test Accuracy: 0.7685185185185185
#               precision    recall  f1-score   support
#
#            1       0.33      0.56      0.42        16
#            2       0.91      0.80      0.86        92
#
#     accuracy                           0.77       108
#    macro avg       0.62      0.68      0.64       108
# weighted avg       0.83      0.77      0.79       108
#
# Confusion Matrix:
#  [[ 9  7]
#  [18 74]]
# Model saved as Decision Tree_model_New.pkl
# ...
# Random Forest Model
# Cross-Validation Accuracy Scores: [0.85714286 0.85714286 0.79761905]
# Mean Cross-Validation Accuracy: 83.73%
# Test Accuracy: 0.8796296296296297
#               precision    recall  f1-score   support
#
#            1       0.57      0.75      0.65        16
#            2       0.95      0.90      0.93        92
#
#     accuracy                           0.88       108
# ...

# %%
pip install shap
# Out:
# ...
#    ---------------------------------------- 0.0/456.1 kB ? eta -:--:--
#     --------------------------------------- 10.2/456.1 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/456.1 kB 435.7 kB/s eta 0:00:01
#    -- ------------------------------------ 30.7/456.1 kB 435.7 kB/s eta 0:00:01
#    -- ------------------------------------ 30.7/456.1 kB 435.7 kB/s eta 0:00:01
#    ----- --------------------------------- 61.4/456.1 kB 252.2 kB/s eta 0:00:02
#    ---------- --------------------------- 122.9/456.1 kB 514.3 kB/s eta 0:00:01
#    ---------- --------------------------- 122.9/456.1 kB 514.3 kB/s eta 0:00:01
#    ---------- --------------------------- 122.9/456.1 kB 514.3 kB/s eta 0:00:01
#    ---------- --------------------------- 122.9/456.1 kB 514.3 kB/s eta 0:00:01
#    --------------- ---------------------- 184.3/456.1 kB 412.5 kB/s eta 0:00:01
#    ----------------- -------------------- 204.8/456.1 kB 461.0 kB/s eta 0:00:01
# ...

# %%
#OLD

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap  # Import SHAP for explainability
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
import pickle

# قراءة ملف Excel
df = pd.read_excel('D:HemoAfterCleaningOld.xlsx')

# فصل المتغيرات المستقلة والتابعة
X1 = df.drop('patient out come', axis=1)
y1 = df['patient out come']

# تقسيم البيانات إلى مجموعات التدريب والاختبار
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=42)

# إعداد النماذج
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machine': SVC(probability=True, random_state=42),  # enable probability for SVC
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier()
}

# إعداد Stratified K-Fold Cross-Validation with 3 folds
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# تدريب النماذج وتقييم الأداء باستخدام Cross-Validation
for model_name, model in models.items():
    print(f"{model_name} Model")
    
    # حساب الدقة لكل نموذج باستخدام Cross-Validation
    cross_val_scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='accuracy')
    print(f"Cross-Validation Accuracy Scores: {cross_val_scores}")
    print(f"Mean Cross-Validation Accuracy: {np.mean(cross_val_scores):.2%}")
    
    # تدريب النموذج وتقييمه على بيانات الاختبار
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Test Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, zero_division=0))  # Control zero_division to handle undefined metrics
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    
   
   
    
    # حفظ النموذج المدرب
    with open(f"{model_name}_model.pkl", 'wb') as file:
        pickle.dump(model, file)
    print(f"Model saved as {model_name}_model.pkl")
    print("=" * 50)  # Separator for clarity
# Out:
# Decision Tree Model
# Cross-Validation Accuracy Scores: [0.72619048 0.73809524 0.66666667]
# Mean Cross-Validation Accuracy: 71.03%
# Test Accuracy: 0.7685185185185185
#               precision    recall  f1-score   support
#
#            1       0.33      0.56      0.42        16
#            2       0.91      0.80      0.86        92
#
#     accuracy                           0.77       108
#    macro avg       0.62      0.68      0.64       108
# weighted avg       0.83      0.77      0.79       108
#
# Confusion Matrix:
#  [[ 9  7]
#  [18 74]]
# Model saved as Decision Tree_model.pkl
# ...
# Random Forest Model
# Cross-Validation Accuracy Scores: [0.85714286 0.85714286 0.79761905]
# Mean Cross-Validation Accuracy: 83.73%
# Test Accuracy: 0.8796296296296297
#               precision    recall  f1-score   support
#
#            1       0.57      0.75      0.65        16
#            2       0.95      0.90      0.93        92
#
#     accuracy                           0.88       108
# ...

# %%
# Best Model Logistic regression and Random Forest , Draw the feature importance OLD
import matplotlib.pyplot as plt
import numpy as np
for model_name, model in models.items():
    print(f"{model_name} Model")
# Feature importance for Random Forest
    if hasattr(models['Random Forest'], 'feature_importances_'):
        rf_importances = models['Random Forest'].feature_importances_
        feature_names = X_train.columns
        # Sorting the feature importances in descending order
        sorted_idx_rf = np.argsort(rf_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_rf], rf_importances[sorted_idx_rf])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Random Forest')
        plt.show()
    
    # Feature importance for Logistic Regression
    if hasattr(models['Logistic Regression'], 'coef_'):
        lr_importances = np.abs(models['Logistic Regression'].coef_[0])  # Get absolute coefficients for binary classification
        sorted_idx_lr = np.argsort(lr_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_lr], lr_importances[sorted_idx_lr])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Logistic Regression')
        plt.show()
    if model_name == 'Gradient Boosting' and hasattr(model, 'feature_importances_'):
        gb_importances = model.feature_importances_
        sorted_idx_gb = np.argsort(gb_importances)[::-1]
        
        plt.figure(figsize=(10, 6))
        plt.barh(feature_names[sorted_idx_gb], gb_importances[sorted_idx_gb])
        plt.xlabel('Feature Importance')
        plt.title('Feature Importance - Gradient Boosting')
        plt.show()
# Out:
# Decision Tree Model
# Random Forest Model
# Support Vector Machine Model
# Logistic Regression Model
# Gradient Boosting Model
# K-Nearest Neighbors Model
